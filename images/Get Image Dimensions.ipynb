# %%
import cv2
import os
import subprocess

inputdir = "." 
for f in os.listdir(inputdir):          
    if not f.endswith("jpg"):
        continue                        
    input_file = inputdir + os.sep + f
    if os.path.isdir(input_file):       
        continue                        
    im = cv2.imread(input_file)
    h, w, c = im.shape
    if h / w <= 1.3:
        continue
    print(input_file, h, w)
    subprocess.check_call(['jpegtran', '-rotate', '90', '-outfile', input_file, input_file], stdout=subprocess.DEVNULL)
# Out:
# ./209c.jpg 276 196
# ./248b.jpg 279 209
# ./240b.jpg 237 166
# ./050d.jpg 292 142
# ./091c.jpg 309 152
# ./263a-t.jpg 162 107
# ./055b.jpg 169 127
# ./057d.jpg 282 135
# ./256a.jpg 232 172
# ./268a-t.jpg 171 112
# ./255b.jpg 267 183
# ./050a.jpg 290 127
# ./292d.jpg 207 133
# ./310b.jpg 256 165
# ./068c.jpg 329 97
# ./244b-t.jpg 244 142
# ./306a.jpg 205 128
# ./050d-t.jpg 289 117
# ./217a.jpg 257 186
# ./113b-t.jpg 369 138
# ./277a-t.jpg 194 90
# ./217b.jpg 263 198
# ./106a.jpg 213 149
# ./093b.jpg 191 67
# ./303a-t.jpg 187 84
# ./311d-t.jpg 189 106
# ./301b.jpg 236 137
# ./231a.jpg 296 214
# ./059c.jpg 329 151
# ./299c-t.jpg 141 72
# ./293a.jpg 233 136
# ./112b.jpg 397 116
# ./112c-t.jpg 412 121
# ./093a-t.jpg 188 141
# ./258c-t.jpg 157 92
# ./088d.jpg 303 98
# ./050c.jpg 287 131
# ./260b-t.jpg 221 136
# ./210c.jpg 202 139
# ./211b.jpg 226 155
# ./094c.jpg 308 157
# ./298c-t.jpg 223 106
# ./255a-t.jpg 221 124
# ./063b-t.jpg 330 157
# ./054a-t.jpg 234 153
# ./061c.jpg 225 122
# ./250a-t.jpg 218 128
# ./092b.jpg 181 81
# ./281b-t.jpg 168 82
# ./310c.jpg 248 140
# ./299d.jpg 152 100
# ./057d-t.jpg 279 140
# ./056b-t.jpg 365 139
# ./052c.jpg 274 127
# ./254c-t.jpg 170 124
# ./229a-t.jpg 171 100
# ./111b-t.jpg 564 142
# ./112a.jpg 401 126
# ./107a-t.jpg 199 96
# ./088c.jpg 314 188
# ./278a.jpg 233 145
# ./257a.jpg 264 167
# ./287d-t.jpg 187 96
# ./257c.jpg 267 184
# ./054d.jpg 236 140
# ./086d.jpg 249 76
# ./223c-t.jpg 214 118
# ./295a.jpg 224 120
# ./108b.jpg 146 67
# ./302b-t.jpg 248 101
# ./229b.jpg 201 137
# ./106b.jpg 241 63
# ./242a.jpg 241 172
# ./286a-t.jpg 198 96
# ./305b-t.jpg 216 94
# ./111b.jpg 562 138
# ./237c.jpg 234 165
# ./033b-t.jpg 184 139
# ./291b-t.jpg 222 115
# ./086b.jpg 249 79
# ./061c-t.jpg 227 125
# ./278d.jpg 229 139
# ./052d-t.jpg 272 104
# ./287a-t.jpg 201 104
# ./290c-t.jpg 198 91
# ./287b-t.jpg 183 105
# ./049a.jpg 601 144
# ./291a.jpg 259 172
# ./209b-t.jpg 137 75
# ./315d.jpg 443 153
# ./112c.jpg 404 120
# ./061d.jpg 221 127
# ./208a.jpg 291 198
# ./209d-t.jpg 143 67
# ./280a.jpg 233 138
# ./233c.jpg 273 197
# ./220b.jpg 281 192
# ./294b.jpg 496 111
# ./296c.jpg 315 174
# ./242c.jpg 248 172
# ./244a.jpg 275 185
# ./239a-t.jpg 164 96
# ./094a.jpg 330 168
# ./289b-t.jpg 294 134
# ./309b.jpg 228 153
# ./106d.jpg 241 74
# ./284b.jpg 263 172
# ./309c-t.jpg 212 91
# ./259c.jpg 244 172
# ./293c.jpg 233 146
# ./209a-t.jpg 230 115
# ./277a.jpg 199 139
# ./115a.jpg 179 95
# ./311b-t.jpg 187 104
# ./062c.jpg 314 163
# ./256a-t.jpg 193 116
# ./246b-t.jpg 216 151
# ./057a.jpg 274 127
# ./059b-t.jpg 328 137
# ./277c.jpg 205 148
# ./259a.jpg 238 159
# ./303c-t.jpg 179 90
# ./214c.jpg 247 182
# ./302a.jpg 269 156
# ./054d-t.jpg 238 136
# ./308a.jpg 275 153
# ./096a.jpg 363 252
# ./088b.jpg 310 85
# ./297b-t.jpg 223 87
# ./204a.jpg 256 181
# ./233a.jpg 276 208
# ./285d.jpg 183 99
# ./237a-t.jpg 195 91
# ./310a.jpg 248 145
# ./119a.jpg 162 102
# ./328a-t.jpg 423 128
# ./289c.jpg 320 156
# ./229c.jpg 214 157
# ./092d.jpg 176 72
# ./231a-t.jpg 256 135
# ./291d-t.jpg 209 106
# ./116a-t.jpg 214 159
# ./105a.jpg 322 185
# ./280a-t.jpg 202 91
# ./113a.jpg 368 125
# ./105d.jpg 346 97
# ./112a-t.jpg 414 111
# ./053d-t.jpg 244 125
# ./216b.jpg 217 159
# ./108d.jpg 146 77
# ./105c.jpg 329 174
# ./085a.jpg 435 180
# ./276c.jpg 228 165
# ./309d-t.jpg 210 99
# ./211c.jpg 231 166
# ./242a-t.jpg 201 117
# ./296b.jpg 314 170
# ./210b.jpg 205 149
# ./274b.jpg 228 159
# ./292b-t.jpg 169 82
# ./305-b.jpg 234 149
# ./053c.jpg 237 118
# ./289a.jpg 320 161
# ./274a-t.jpg 215 122
# ./295d-t.jpg 193 89
# ./296b-t.jpg 267 116
# ./293c-t.jpg 215 92
# ./049c-t.jpg 602 139
# ./221b.jpg 247 157
# ./057a-t.jpg 275 119
# ./086c.jpg 256 175
# ./091d.jpg 317 86
# ./213a-t.jpg 223 134
# ./294a.jpg 499 154
# ./282a.jpg 269 198
# ./226c.jpg 287 195
# ./238c.jpg 254 190
# ./291c-t.jpg 205 112

# %%
import string

ids = [("000" + str(x))[-3:] for x in range(1, 400)]

for id in ids:
    for finfo in [('Facsimile', '-t'), ('Photo', '')]:
        suffix = finfo[0]
        x = finfo[1]
        cmd = ['convert']
        for e in string.ascii_lowercase[:6]:
            f = id + e + x + ".jpg"
            input_file = inputdir + os.sep + f
            if not os.path.isfile(input_file):
                continue
            if len(cmd) > 1:
                cmd.extend([f, "-append"])
            else:
                cmd.extend([f])
        if len(cmd) == 1:
            continue
        cmd.append(id + '-' + suffix + '.jpg')
        subprocess.check_call(cmd, stdout=subprocess.DEVNULL)

# %%
import cv2
import os
import subprocess
import string

ids = ["260b.jpg"]
inputdir = "." 
for f in os.listdir(inputdir):          
    if f not in ids:
        continue                        
    input_file = inputdir + os.sep + f
    if os.path.isdir(input_file):       
        continue                        
    im = cv2.imread(input_file)
    subprocess.check_call(['jpegtran', '-rotate', '90', '-outfile', input_file, input_file], stdout=subprocess.DEVNULL)

ids = ["260"]
for id in ids:
    for finfo in [('Facsimile', '-t'), ('Photo', '')]:
        suffix = finfo[0]
        x = finfo[1]
        cmd = ['convert']
        for e in string.ascii_lowercase[:6]:
            f = id + e + x + ".jpg"
            input_file = inputdir + os.sep + f
            if not os.path.isfile(input_file):
                continue
            if len(cmd) > 1:
                cmd.extend([f, "-append"])
            else:
                cmd.extend([f])
        if len(cmd) == 1:
            continue
        cmd.append(id + '-' + suffix + '.jpg')
        subprocess.check_call(cmd, stdout=subprocess.DEVNULL)

# %%
import cv2
import os
import subprocess
import string

ids = ["297c-5.jpg"]
inputdir = "." 
for f in os.listdir(inputdir):          
    if f not in ids:
        continue                        
    input_file = inputdir + os.sep + f
    if os.path.isdir(input_file):       
        continue                        
    im = cv2.imread(input_file)
    h, w, c = im.shape
    if h / w <= 1.3:
        continue
    print(input_file, h, w)
    subprocess.check_call(['jpegtran', '-rotate', '90', '-outfile', input_file, input_file], stdout=subprocess.DEVNULL)

# %%
import os
import subprocess
import string


ids = ["035"]
inputdir = "." 

for id in ids:
    for finfo in [('Facsimile', '-t'), ('Photo', '')]:
        suffix = finfo[0]
        x = finfo[1]
        cmd = ['convert']
        for e in string.ascii_lowercase[:6]:
            f = id + e + x + ".jpg"
            input_file = inputdir + os.sep + f
            if not os.path.isfile(input_file):
                continue
            if len(cmd) > 1:
                cmd.extend([f, "-append"])
            else:
                cmd.extend([f])
        if len(cmd) == 1:
            continue
        cmd.append(id + '-' + suffix + '.jpg')
        subprocess.check_call(cmd, stdout=subprocess.DEVNULL)

# %%
ids = [("000" + str(x))[-3:] for x in range(0, 400)]
ids
# Out:
# ['000',
#  '001',
#  '002',
#  '003',
#  '004',
#  '005',
#  '006',
#  '007',
#  '008',
#  '009',
#  '010',
#  '011',
#  '012',
#  '013',
#  '014',
#  '015',
#  '016',
#  '017',
#  '018',
#  '019',
#  '020',
#  '021',
#  '022',
#  '023',
#  '024',
#  '025',
#  '026',
#  '027',
#  '028',
#  '029',
#  '030',
#  '031',
#  '032',
#  '033',
#  '034',
#  '035',
#  '036',
#  '037',
#  '038',
#  '039',
#  '040',
#  '041',
#  '042',
#  '043',
#  '044',
#  '045',
#  '046',
#  '047',
#  '048',
#  '049',
#  '050',
#  '051',
#  '052',
#  '053',
#  '054',
#  '055',
#  '056',
#  '057',
#  '058',
#  '059',
#  '060',
#  '061',
#  '062',
#  '063',
#  '064',
#  '065',
#  '066',
#  '067',
#  '068',
#  '069',
#  '070',
#  '071',
#  '072',
#  '073',
#  '074',
#  '075',
#  '076',
#  '077',
#  '078',
#  '079',
#  '080',
#  '081',
#  '082',
#  '083',
#  '084',
#  '085',
#  '086',
#  '087',
#  '088',
#  '089',
#  '090',
#  '091',
#  '092',
#  '093',
#  '094',
#  '095',
#  '096',
#  '097',
#  '098',
#  '099',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '130',
#  '131',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '140',
#  '141',
#  '142',
#  '143',
#  '144',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '151',
#  '152',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '160',
#  '161',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '169',
#  '170',
#  '171',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '177',
#  '178',
#  '179',
#  '180',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '188',
#  '189',
#  '190',
#  '191',
#  '192',
#  '193',
#  '194',
#  '195',
#  '196',
#  '197',
#  '198',
#  '199',
#  '200',
#  '201',
#  '202',
#  '203',
#  '204',
#  '205',
#  '206',
#  '207',
#  '208',
#  '209',
#  '210',
#  '211',
#  '212',
#  '213',
#  '214',
#  '215',
#  '216',
#  '217',
#  '218',
#  '219',
#  '220',
#  '221',
#  '222',
#  '223',
#  '224',
#  '225',
#  '226',
#  '227',
#  '228',
#  '229',
#  '230',
#  '231',
#  '232',
#  '233',
#  '234',
#  '235',
#  '236',
#  '237',
#  '238',
#  '239',
#  '240',
#  '241',
#  '242',
#  '243',
#  '244',
#  '245',
#  '246',
#  '247',
#  '248',
#  '249',
#  '250',
#  '251',
#  '252',
#  '253',
#  '254',
#  '255',
#  '256',
#  '257',
#  '258',
#  '259',
#  '260',
#  '261',
#  '262',
#  '263',
#  '264',
#  '265',
#  '266',
#  '267',
#  '268',
#  '269',
#  '270',
#  '271',
#  '272',
#  '273',
#  '274',
#  '275',
#  '276',
#  '277',
#  '278',
#  '279',
#  '280',
#  '281',
#  '282',
#  '283',
#  '284',
#  '285',
#  '286',
#  '287',
#  '288',
#  '289',
#  '290',
#  '291',
#  '292',
#  '293',
#  '294',
#  '295',
#  '296',
#  '297',
#  '298',
#  '299',
#  '300',
#  '301',
#  '302',
#  '303',
#  '304',
#  '305',
#  '306',
#  '307',
#  '308',
#  '309',
#  '310',
#  '311',
#  '312',
#  '313',
#  '314',
#  '315',
#  '316',
#  '317',
#  '318',
#  '319',
#  '320',
#  '321',
#  '322',
#  '323',
#  '324',
#  '325',
#  '326',
#  '327',
#  '328',
#  '329',
#  '330',
#  '331',
#  '332',
#  '333',
#  '334',
#  '335',
#  '336',
#  '337',
#  '338',
#  '339',
#  '340',
#  '341',
#  '342',
#  '343',
#  '344',
#  '345',
#  '346',
#  '347',
#  '348',
#  '349',
#  '350',
#  '351',
#  '352',
#  '353',
#  '354',
#  '355',
#  '356',
#  '357',
#  '358',
#  '359',
#  '360',
#  '361',
#  '362',
#  '363',
#  '364',
#  '365',
#  '366',
#  '367',
#  '368',
#  '369',
#  '370',
#  '371',
#  '372',
#  '373',
#  '374',
#  '375',
#  '376',
#  '377',
#  '378',
#  '379',
#  '380',
#  '381',
#  '382',
#  '383',
#  '384',
#  '385',
#  '386',
#  '387',
#  '388',
#  '389',
#  '390',
#  '391',
#  '392',
#  '393',
#  '394',
#  '395',
#  '396',
#  '397',
#  '398',
#  '399']

# %%
import csv

input_file = open("../../CretanHiero/000-CHIC-To-Unicode.csv", 'r')              
input_csv_file = csv.DictReader(input_file, delimiter=',')     
for row in input_csv_file:                                     
    tn = row["Cº"]
    if tn == "042":
        print(row)
# Out:
# OrderedDict([('Index', '57'), ('code', 'F2038'), ('glyph', '\U000f2038'), ('Sº', '036'), ('Cº', '042'), ('SM I item', '024 a'), ('CHIC item', '255'), ('CMS item', '')])
# OrderedDict([('Index', '58'), ('code', 'F2039'), ('glyph', '\U000f2039'), ('Sº', '036'), ('Cº', '042'), ('SM I item', '103 d, 064 c, 109 a'), ('CHIC item', '058, 027, 050'), ('CMS item', '')])
# OrderedDict([('Index', '202'), ('code', 'F20C9'), ('glyph', '\U000f20c9'), ('Sº', '128'), ('Cº', '042'), ('SM I item', '088 b'), ('CHIC item', '033'), ('CMS item', '')])
# OrderedDict([('Index', '291'), ('code', 'F2126'), ('glyph', '\U000f2126'), ('Sº', '036'), ('Cº', '042'), ('SM I item', '064'), ('CHIC item', '027 β'), ('CMS item', '')])
# OrderedDict([('Index', '292'), ('code', 'F2127'), ('glyph', '\U000f2127'), ('Sº', '036'), ('Cº', '042'), ('SM I item', ''), ('CHIC item', '134'), ('CMS item', '')])
# OrderedDict([('Index', '462'), ('code', 'F21D9'), ('glyph', '\U000f21d9'), ('Sº', '036'), ('Cº', '042'), ('SM I item', '064'), ('CHIC item', '027'), ('CMS item', '')])
# OrderedDict([('Index', '851'), ('code', 'F235E'), ('glyph', '\U000f235e'), ('Sº', '036'), ('Cº', '042'), ('SM I item', ''), ('CHIC item', '276'), ('CMS item', 'IV, 135')])
# OrderedDict([('Index', '890'), ('code', 'F2385'), ('glyph', '\U000f2385'), ('Sº', '036'), ('Cº', '042'), ('SM I item', ''), ('CHIC item', '293'), ('CMS item', 'II 2, 256')])
# OrderedDict([('Index', '941'), ('code', 'F23B8'), ('glyph', '\U000f23b8'), ('Sº', '036'), ('Cº', '042'), ('SM I item', ''), ('CHIC item', '305'), ('CMS item', 'IV, 136')])
# OrderedDict([('Index', '942'), ('code', 'F23B9'), ('glyph', '\U000f23b9'), ('Sº', '036'), ('Cº', '042'), ('SM I item', ''), ('CHIC item', '305'), ('CMS item', 'IV, 136')])

# %%
test = "023, 123"
t = [x.strip() for x in test.split(",")]
t
# Out:
# ['023', '123']
